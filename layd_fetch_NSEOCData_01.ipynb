# %%
import requests
import json
import pandas as pd

url = 'https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY'

headers={'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
response = requests.get(url, headers=headers, timeout=10)

# %%
response_text=response.text
json_object = json.loads(response_text)

#print(json_object)

with open("OC.json", "w") as outfile:
    outfile.write(response_text)

# Below 'data' os a list 
data = json_object['records']['data']
print(type(data))
# Out:
# <class 'list'>

# %%
# prepare list of expiry date from json_object. This list will be used to fetah OC date based on expiry date
e_date=json_object['records']['expiryDates']

# %%
oc_data = {}
for ed in e_date:
    oc_data[ed]={"CE":[], "PE":[]}
    for di in range(len(data)):
        
        if data[di]['expiryDate'] == ed:
            if 'CE' in data[di].keys() and data[di]['CE']['expiryDate'] == ed:
                
                oc_data[ed]["CE"].append(data[di]['CE'])
            else:
                oc_data[ed]["CE"].append('-')

            if 'PE' in data[di].keys() and data[di]['PE']['expiryDate'] == ed:
                oc_data[ed]["PE"].append(data[di]['PE'])
                
            else:
                oc_data[ed]["PE"].append('-')

# %%
# This loop is to delete extra keys from oc_data
for k in oc_data.keys():
    
    for i in range(len(oc_data[k]["CE"])):
        
        if oc_data[k]["CE"][i] != '-':
        
            del oc_data[k]["CE"][i]["expiryDate"]
            del oc_data[k]["CE"][i]["underlying"]
            del oc_data[k]["CE"][i]["identifier"]

        if oc_data[k]["PE"][i] != '-':

            del oc_data[k]["PE"][i]["expiryDate"]
            del oc_data[k]["PE"][i]["underlying"]
            del oc_data[k]["PE"][i]["identifier"]

# %%
oc_data
# Out:
# {'12-Jan-2023': {'CE': [{'strikePrice': 16300,
#     'openInterest': 1,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 1713.05,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 8400,
#     'totalSellQuantity': 9900,
#     'bidQty': 300,
#     'bidprice': 1782.75,
#     'askQty': 1500,
#     'askPrice': 1848.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16350,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 7800,
#     'totalSellQuantity': 6300,
#     'bidQty': 1500,
#     'bidprice': 1711.1,
#     'askQty': 1800,
#     'askPrice': 1783.05,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16400,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 11400,
#     'totalSellQuantity': 11400,
#     'bidQty': 1500,
#     'bidprice': 1660.4,
#     'askQty': 1500,
#     'askPrice': 1748.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16450,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 9600,
#     'totalSellQuantity': 9600,
#     'bidQty': 1500,
#     'bidprice': 1610.95,
#     'askQty': 1500,
#     'askPrice': 1712.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16500,
#     'openInterest': 109,
#     'changeinOpenInterest': -1,
#     'pchangeinOpenInterest': -0.9090909090909091,
#     'totalTradedVolume': 8,
#     'impliedVolatility': 0,
#     'lastPrice': 1605,
#     'change': 243.0999999999999,
#     'pChange': 17.85006241280563,
#     'totalBuyQuantity': 15050,
#     'totalSellQuantity': 11200,
#     'bidQty': 200,
#     'bidprice': 1591.95,
#     'askQty': 800,
#     'askPrice': 1626,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16550,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 1805.5,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 8100,
#     'totalSellQuantity': 9600,
#     'bidQty': 1800,
#     'bidprice': 1510.55,
#     'askQty': 1500,
#     'askPrice': 1606.65,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16600,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 8600,
#     'totalSellQuantity': 8600,
#     'bidQty': 200,
#     'bidprice': 1471.5,
#     'askQty': 100,
#     'askPrice': 1530.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16650,
#     'openInterest': 2,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 1362.7,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 8100,
#     'totalSellQuantity': 8100,
#     'bidQty': 1800,
#     'bidprice': 1411.4,
#     'askQty': 1800,
#     'askPrice': 1482.15,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16700,
#     'openInterest': 16,
#     'changeinOpenInterest': 11,
#     'pchangeinOpenInterest': 220,
#     'totalTradedVolume': 22,
#     'impliedVolatility': 0,
#     'lastPrice': 1398.8,
#     'change': 218.79999999999995,
#     'pChange': 18.542372881355927,
#     'totalBuyQuantity': 10150,
#     'totalSellQuantity': 8950,
#     'bidQty': 750,
#     'bidprice': 1377.95,
#     'askQty': 350,
#     'askPrice': 1398.45,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16750,
#     'openInterest': 2,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 1375.25,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 8100,
#     'totalSellQuantity': 8100,
#     'bidQty': 1800,
#     'bidprice': 1311.1,
#     'askQty': 1800,
#     'askPrice': 1383,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16800,
#     'openInterest': 34,
#     'changeinOpenInterest': 1,
#     'pchangeinOpenInterest': 3.0303030303030303,
#     'totalTradedVolume': 9,
#     'impliedVolatility': 51.85,
#     'lastPrice': 1333.85,
#     'change': 263.8499999999999,
#     'pChange': 24.658878504672888,
#     'totalBuyQuantity': 9350,
#     'totalSellQuantity': 11150,
#     'bidQty': 50,
#     'bidprice': 1293.25,
#     'askQty': 300,
#     'askPrice': 1308.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16850,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 8500,
#     'totalSellQuantity': 8500,
#     'bidQty': 100,
#     'bidprice': 1238.45,
#     'askQty': 100,
#     'askPrice': 1292.75,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16900,
#     'openInterest': 16,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 4,
#     'impliedVolatility': 0,
#     'lastPrice': 1077.25,
#     'change': 79.25,
#     'pChange': 7.940881763527054,
#     'totalBuyQuantity': 9850,
#     'totalSellQuantity': 9850,
#     'bidQty': 300,
#     'bidprice': 1173.65,
#     'askQty': 100,
#     'askPrice': 1227.25,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16950,
#     'openInterest': 0,
#     'changeinOpenInterest': -1,
#     'pchangeinOpenInterest': -100,
#     'totalTradedVolume': 3,
#     'impliedVolatility': 0,
#     'lastPrice': 1161.3,
#     'change': 219.04999999999995,
#     'pChange': 23.247545768108246,
#     'totalBuyQuantity': 9300,
#     'totalSellQuantity': 9300,
#     'bidQty': 100,
#     'bidprice': 1139.65,
#     'askQty': 100,
#     'askPrice': 1177.75,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17000,
#     'openInterest': 2718,
#     'changeinOpenInterest': 581,
#     'pchangeinOpenInterest': 27.18764623303697,
#     'totalTradedVolume': 2113,
#     'impliedVolatility': 0,
#     'lastPrice': 1095.55,
#     'change': 209.14999999999998,
#     'pChange': 23.595442238267143,
#     'totalBuyQuantity': 20050,
#     'totalSellQuantity': 10750,
#     'bidQty': 100,
#     'bidprice': 1095.15,
#     'askQty': 200,
#     'askPrice': 1098.7,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17050,
#     'openInterest': 5,
#     'changeinOpenInterest': 2,
#     'pchangeinOpenInterest': 66.66666666666667,
#     'totalTradedVolume': 4,
#     'impliedVolatility': 0,
#     'lastPrice': 1043.35,
#     'change': 239.7499999999999,
#     'pChange': 29.83449477351915,
#     'totalBuyQuantity': 11150,
#     'totalSellQuantity': 10850,
#     'bidQty': 300,
#     'bidprice': 1040.8,
#     'askQty': 50,
#     'askPrice': 1077.95,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17100,
#     'openInterest': 110,
#     'changeinOpenInterest': 20,
#     'pchangeinOpenInterest': 22.22222222222222,
#     'totalTradedVolume': 35,
#     'impliedVolatility': 0,
#     'lastPrice': 923.35,
#     'change': 145.5,
#     'pChange': 18.70540592659253,
#     'totalBuyQuantity': 12300,
#     'totalSellQuantity': 11900,
#     'bidQty': 500,
#     'bidprice': 980.9,
#     'askQty': 300,
#     'askPrice': 1027,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17150,
#     'openInterest': 137,
#     'changeinOpenInterest': 32,
#     'pchangeinOpenInterest': 30.476190476190474,
#     'totalTradedVolume': 75,
#     'impliedVolatility': 0,
#     'lastPrice': 950.9,
#     'change': 214.35000000000002,
#     'pChange': 29.1018939651076,
#     'totalBuyQuantity': 11650,
#     'totalSellQuantity': 11850,
#     'bidQty': 550,
#     'bidprice': 945.35,
#     'askQty': 300,
#     'askPrice': 952.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17200,
#     'openInterest': 357,
#     'changeinOpenInterest': 151,
#     'pchangeinOpenInterest': 73.30097087378641,
#     'totalTradedVolume': 290,
#     'impliedVolatility': 0,
#     'lastPrice': 900.8,
#     'change': 212.75,
#     'pChange': 30.92071797107769,
#     'totalBuyQuantity': 418150,
#     'totalSellQuantity': 11000,
#     'bidQty': 300,
#     'bidprice': 890.6,
#     'askQty': 1200,
#     'askPrice': 922.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17250,
#     'openInterest': 57,
#     'changeinOpenInterest': 54,
#     'pchangeinOpenInterest': 1800,
#     'totalTradedVolume': 67,
#     'impliedVolatility': 0,
#     'lastPrice': 853.05,
#     'change': 222.25,
#     'pChange': 35.23303741280913,
#     'totalBuyQuantity': 42350,
#     'totalSellQuantity': 11000,
#     'bidQty': 1200,
#     'bidprice': 837.25,
#     'askQty': 200,
#     'askPrice': 853.55,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17300,
#     'openInterest': 224,
#     'changeinOpenInterest': 21,
#     'pchangeinOpenInterest': 10.344827586206897,
#     'totalTradedVolume': 179,
#     'impliedVolatility': 0,
#     'lastPrice': 801.8,
#     'change': 206.25,
#     'pChange': 34.63185290907565,
#     'totalBuyQuantity': 280400,
#     'totalSellQuantity': 11150,
#     'bidQty': 1350,
#     'bidprice': 792.1,
#     'askQty': 100,
#     'askPrice': 803.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17350,
#     'openInterest': 176,
#     'changeinOpenInterest': 78,
#     'pchangeinOpenInterest': 79.59183673469387,
#     'totalTradedVolume': 116,
#     'impliedVolatility': 28.78,
#     'lastPrice': 774.85,
#     'change': 244.55000000000007,
#     'pChange': 46.11540637375072,
#     'totalBuyQuantity': 13200,
#     'totalSellQuantity': 11350,
#     'bidQty': 450,
#     'bidprice': 744.25,
#     'askQty': 1650,
#     'askPrice': 777.2,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17400,
#     'openInterest': 953,
#     'changeinOpenInterest': 212,
#     'pchangeinOpenInterest': 28.60998650472335,
#     'totalTradedVolume': 1109,
#     'impliedVolatility': 0,
#     'lastPrice': 699.85,
#     'change': 212.5,
#     'pChange': 43.60315994665025,
#     'totalBuyQuantity': 21650,
#     'totalSellQuantity': 13600,
#     'bidQty': 100,
#     'bidprice': 698,
#     'askQty': 50,
#     'askPrice': 700.2,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17450,
#     'openInterest': 402,
#     'changeinOpenInterest': 204,
#     'pchangeinOpenInterest': 103.03030303030303,
#     'totalTradedVolume': 677,
#     'impliedVolatility': 0,
#     'lastPrice': 662.9,
#     'change': 218.25,
#     'pChange': 49.083548858652875,
#     'totalBuyQuantity': 13550,
#     'totalSellQuantity': 10650,
#     'bidQty': 150,
#     'bidprice': 647.15,
#     'askQty': 1350,
#     'askPrice': 678.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17500,
#     'openInterest': 5154,
#     'changeinOpenInterest': 2381,
#     'pchangeinOpenInterest': 85.8636855391273,
#     'totalTradedVolume': 12615,
#     'impliedVolatility': 0,
#     'lastPrice': 601.8,
#     'change': 202.34999999999997,
#     'pChange': 50.65715358618099,
#     'totalBuyQuantity': 165000,
#     'totalSellQuantity': 13850,
#     'bidQty': 50,
#     'bidprice': 599.25,
#     'askQty': 50,
#     'askPrice': 602.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17550,
#     'openInterest': 527,
#     'changeinOpenInterest': 34,
#     'pchangeinOpenInterest': 6.896551724137931,
#     'totalTradedVolume': 963,
#     'impliedVolatility': 0,
#     'lastPrice': 548.85,
#     'change': 196.45000000000005,
#     'pChange': 55.74631101021568,
#     'totalBuyQuantity': 120100,
#     'totalSellQuantity': 9650,
#     'bidQty': 250,
#     'bidprice': 521.85,
#     'askQty': 300,
#     'askPrice': 553.75,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17600,
#     'openInterest': 1129,
#     'changeinOpenInterest': -389,
#     'pchangeinOpenInterest': -25.62582345191041,
#     'totalTradedVolume': 6134,
#     'impliedVolatility': 0,
#     'lastPrice': 499.95,
#     'change': 188.8,
#     'pChange': 60.67812951952435,
#     'totalBuyQuantity': 18550,
#     'totalSellQuantity': 12750,
#     'bidQty': 50,
#     'bidprice': 499.1,
#     'askQty': 50,
#     'askPrice': 502.8,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17650,
#     'openInterest': 903,
#     'changeinOpenInterest': -184,
#     'pchangeinOpenInterest': -16.927322907083717,
#     'totalTradedVolume': 2040,
#     'impliedVolatility': 0,
#     'lastPrice': 453.25,
#     'change': 183.5,
#     'pChange': 68.0259499536608,
#     'totalBuyQuantity': 11950,
#     'totalSellQuantity': 11600,
#     'bidQty': 450,
#     'bidprice': 425.55,
#     'askQty': 350,
#     'askPrice': 453.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17700,
#     'openInterest': 4504,
#     'changeinOpenInterest': -1247,
#     'pchangeinOpenInterest': -21.68318553295079,
#     'totalTradedVolume': 26489,
#     'impliedVolatility': 0,
#     'lastPrice': 402.4,
#     'change': 174.09999999999997,
#     'pChange': 76.25930792816467,
#     'totalBuyQuantity': 35250,
#     'totalSellQuantity': 16350,
#     'bidQty': 150,
#     'bidprice': 403.5,
#     'askQty': 150,
#     'askPrice': 405.25,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17750,
#     'openInterest': 3811,
#     'changeinOpenInterest': -1294,
#     'pchangeinOpenInterest': -25.34769833496572,
#     'totalTradedVolume': 16434,
#     'impliedVolatility': 0,
#     'lastPrice': 354.9,
#     'change': 162.79999999999998,
#     'pChange': 84.74752732951588,
#     'totalBuyQuantity': 33100,
#     'totalSellQuantity': 13100,
#     'bidQty': 300,
#     'bidprice': 354.35,
#     'askQty': 150,
#     'askPrice': 356.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17800,
#     'openInterest': 14073,
#     'changeinOpenInterest': -22594,
#     'pchangeinOpenInterest': -61.619439823274334,
#     'totalTradedVolume': 196857,
#     'impliedVolatility': 0,
#     'lastPrice': 308,
#     'change': 149.5,
#     'pChange': 94.3217665615142,
#     'totalBuyQuantity': 54250,
#     'totalSellQuantity': 26600,
#     'bidQty': 200,
#     'bidprice': 308,
#     'askQty': 1000,
#     'askPrice': 309,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17850,
#     'openInterest': 4648,
#     'changeinOpenInterest': -12037,
#     'pchangeinOpenInterest': -72.14264309259814,
#     'totalTradedVolume': 130603,
#     'impliedVolatility': 0,
#     'lastPrice': 262,
#     'change': 133.3,
#     'pChange': 103.5742035742036,
#     'totalBuyQuantity': 37750,
#     'totalSellQuantity': 13700,
#     'bidQty': 750,
#     'bidprice': 261.45,
#     'askQty': 50,
#     'askPrice': 263.95,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17900,
#     'openInterest': 15041,
#     'changeinOpenInterest': -81357,
#     'pchangeinOpenInterest': -84.39697919043964,
#     'totalTradedVolume': 721989,
#     'impliedVolatility': 8.57,
#     'lastPrice': 219.6,
#     'change': 117.35,
#     'pChange': 114.76772616136918,
#     'totalBuyQuantity': 72550,
#     'totalSellQuantity': 40100,
#     'bidQty': 150,
#     'bidprice': 218.05,
#     'askQty': 50,
#     'askPrice': 219.45,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17950,
#     'openInterest': 7396,
#     'changeinOpenInterest': -28323,
#     'pchangeinOpenInterest': -79.29393320081749,
#     'totalTradedVolume': 529298,
#     'impliedVolatility': 9.7,
#     'lastPrice': 178,
#     'change': 97.7,
#     'pChange': 121.66874221668742,
#     'totalBuyQuantity': 44200,
#     'totalSellQuantity': 38350,
#     'bidQty': 50,
#     'bidprice': 178,
#     'askQty': 500,
#     'askPrice': 178.5,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18000,
#     'openInterest': 120123,
#     'changeinOpenInterest': -119094,
#     'pchangeinOpenInterest': -49.7849233123064,
#     'totalTradedVolume': 2923048,
#     'impliedVolatility': 10.2,
#     'lastPrice': 140,
#     'change': 77.85,
#     'pChange': 125.26146419951729,
#     'totalBuyQuantity': 679300,
#     'totalSellQuantity': 295350,
#     'bidQty': 350,
#     'bidprice': 138.5,
#     'askQty': 2500,
#     'askPrice': 140,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18050,
#     'openInterest': 25208,
#     'changeinOpenInterest': -20612,
#     'pchangeinOpenInterest': -44.98472282845919,
#     'totalTradedVolume': 1678677,
#     'impliedVolatility': 10.56,
#     'lastPrice': 107,
#     'change': 59.45,
#     'pChange': 125.02628811777079,
#     'totalBuyQuantity': 113400,
#     'totalSellQuantity': 135250,
#     'bidQty': 1100,
#     'bidprice': 106,
#     'askQty': 550,
#     'askPrice': 107,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18100,
#     'openInterest': 136487,
#     'changeinOpenInterest': -5574,
#     'pchangeinOpenInterest': -3.9236665939279605,
#     'totalTradedVolume': 4272307,
#     'impliedVolatility': 10.65,
#     'lastPrice': 78,
#     'change': 42.35,
#     'pChange': 118.79382889200562,
#     'totalBuyQuantity': 290700,
#     'totalSellQuantity': 888050,
#     'bidQty': 150,
#     'bidprice': 78,
#     'askQty': 50,
#     'askPrice': 78.3,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18150,
#     'openInterest': 63075,
#     'changeinOpenInterest': 8975,
#     'pchangeinOpenInterest': 16.589648798521257,
#     'totalTradedVolume': 1956675,
#     'impliedVolatility': 10.78,
#     'lastPrice': 55,
#     'change': 28.8,
#     'pChange': 109.92366412213741,
#     'totalBuyQuantity': 106050,
#     'totalSellQuantity': 461850,
#     'bidQty': 50,
#     'bidprice': 54.95,
#     'askQty': 8000,
#     'askPrice': 55,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18200,
#     'openInterest': 131068,
#     'changeinOpenInterest': -5760,
#     'pchangeinOpenInterest': -4.209664688514047,
#     'totalTradedVolume': 3233202,
#     'impliedVolatility': 11.02,
#     'lastPrice': 38,
#     'change': 18.85,
#     'pChange': 98.43342036553526,
#     'totalBuyQuantity': 393800,
#     'totalSellQuantity': 1093900,
#     'bidQty': 9850,
#     'bidprice': 38,
#     'askQty': 22400,
#     'askPrice': 38.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18250,
#     'openInterest': 59320,
#     'changeinOpenInterest': 9130,
#     'pchangeinOpenInterest': 18.190874676230326,
#     'totalTradedVolume': 1419649,
#     'impliedVolatility': 11.18,
#     'lastPrice': 25.15,
#     'change': 11.45,
#     'pChange': 83.57664233576642,
#     'totalBuyQuantity': 223350,
#     'totalSellQuantity': 319100,
#     'bidQty': 2850,
#     'bidprice': 25,
#     'askQty': 100,
#     'askPrice': 25.7,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18300,
#     'openInterest': 143229,
#     'changeinOpenInterest': 34928,
#     'pchangeinOpenInterest': 32.25085640945144,
#     'totalTradedVolume': 2327918,
#     'impliedVolatility': 11.26,
#     'lastPrice': 15.8,
#     'change': 5.75,
#     'pChange': 57.2139303482587,
#     'totalBuyQuantity': 293250,
#     'totalSellQuantity': 759800,
#     'bidQty': 2750,
#     'bidprice': 15.75,
#     'askQty': 100,
#     'askPrice': 16.15,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18350,
#     'openInterest': 56245,
#     'changeinOpenInterest': -2853,
#     'pchangeinOpenInterest': -4.827574537209381,
#     'totalTradedVolume': 1184104,
#     'impliedVolatility': 11.48,
#     'lastPrice': 9.95,
#     'change': 2.549999999999999,
#     'pChange': 34.459459459459445,
#     'totalBuyQuantity': 107400,
#     'totalSellQuantity': 249900,
#     'bidQty': 50,
#     'bidprice': 9.9,
#     'askQty': 2250,
#     'askPrice': 10,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18400,
#     'openInterest': 118299,
#     'changeinOpenInterest': 20305,
#     'pchangeinOpenInterest': 20.72065636671633,
#     'totalTradedVolume': 1619832,
#     'impliedVolatility': 11.86,
#     'lastPrice': 6.5,
#     'change': 0.7000000000000002,
#     'pChange': 12.068965517241383,
#     'totalBuyQuantity': 170000,
#     'totalSellQuantity': 435400,
#     'bidQty': 100,
#     'bidprice': 6.5,
#     'askQty': 50,
#     'askPrice': 6.55,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18450,
#     'openInterest': 48324,
#     'changeinOpenInterest': 10400,
#     'pchangeinOpenInterest': 27.423267587807192,
#     'totalTradedVolume': 812151,
#     'impliedVolatility': 12.43,
#     'lastPrice': 4.55,
#     'change': -0.10000000000000053,
#     'pChange': -2.1505376344086136,
#     'totalBuyQuantity': 117200,
#     'totalSellQuantity': 147600,
#     'bidQty': 50,
#     'bidprice': 4.45,
#     'askQty': 550,
#     'askPrice': 4.55,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18500,
#     'openInterest': 122820,
#     'changeinOpenInterest': 3111,
#     'pchangeinOpenInterest': 2.5988020950805706,
#     'totalTradedVolume': 1328452,
#     'impliedVolatility': 13.29,
#     'lastPrice': 3.65,
#     'change': -0.3500000000000001,
#     'pChange': -8.750000000000002,
#     'totalBuyQuantity': 638850,
#     'totalSellQuantity': 516250,
#     'bidQty': 100,
#     'bidprice': 3.6,
#     'askQty': 150,
#     'askPrice': 3.65,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18550,
#     'openInterest': 24998,
#     'changeinOpenInterest': -5935,
#     'pchangeinOpenInterest': -19.186629166262566,
#     'totalTradedVolume': 466656,
#     'impliedVolatility': 14.16,
#     'lastPrice': 3,
#     'change': -0.5499999999999998,
#     'pChange': -15.492957746478869,
#     'totalBuyQuantity': 52450,
#     'totalSellQuantity': 95950,
#     'bidQty': 1950,
#     'bidprice': 2.6,
#     'askQty': 3300,
#     'askPrice': 3,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18600,
#     'openInterest': 108684,
#     'changeinOpenInterest': 2686,
#     'pchangeinOpenInterest': 2.534010075661805,
#     'totalTradedVolume': 900757,
#     'impliedVolatility': 15.1,
#     'lastPrice': 2.6,
#     'change': -0.5499999999999998,
#     'pChange': -17.460317460317455,
#     'totalBuyQuantity': 347400,
#     'totalSellQuantity': 150350,
#     'bidQty': 18300,
#     'bidprice': 2.55,
#     'askQty': 1000,
#     'askPrice': 2.65,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18650,
#     'openInterest': 14729,
#     'changeinOpenInterest': 925,
#     'pchangeinOpenInterest': 6.700956244566792,
#     'totalTradedVolume': 211950,
#     'impliedVolatility': 15.83,
#     'lastPrice': 2.1,
#     'change': -0.6499999999999999,
#     'pChange': -23.636363636363633,
#     'totalBuyQuantity': 38200,
#     'totalSellQuantity': 66550,
#     'bidQty': 50,
#     'bidprice': 2.05,
#     'askQty': 50,
#     'askPrice': 2.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18700,
#     'openInterest': 100462,
#     'changeinOpenInterest': 27613,
#     'pchangeinOpenInterest': 37.90443245617647,
#     'totalTradedVolume': 557843,
#     'impliedVolatility': 16.87,
#     'lastPrice': 1.95,
#     'change': -0.6500000000000001,
#     'pChange': -25.000000000000007,
#     'totalBuyQuantity': 785050,
#     'totalSellQuantity': 172650,
#     'bidQty': 3400,
#     'bidprice': 1.8,
#     'askQty': 3250,
#     'askPrice': 2.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18750,
#     'openInterest': 11767,
#     'changeinOpenInterest': 1868,
#     'pchangeinOpenInterest': 18.87059298919083,
#     'totalTradedVolume': 94854,
#     'impliedVolatility': 18.06,
#     'lastPrice': 1.95,
#     'change': -0.40000000000000013,
#     'pChange': -17.021276595744688,
#     'totalBuyQuantity': 66750,
#     'totalSellQuantity': 71550,
#     'bidQty': 100,
#     'bidprice': 1.65,
#     'askQty': 550,
#     'askPrice': 2,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18800,
#     'openInterest': 66856,
#     'changeinOpenInterest': -9042,
#     'pchangeinOpenInterest': -11.913357400722022,
#     'totalTradedVolume': 309509,
#     'impliedVolatility': 18.72,
#     'lastPrice': 1.6,
#     'change': -0.6499999999999999,
#     'pChange': -28.888888888888886,
#     'totalBuyQuantity': 1105900,
#     'totalSellQuantity': 148250,
#     'bidQty': 2100,
#     'bidprice': 1.45,
#     'askQty': 50,
#     'askPrice': 1.6,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18850,
#     'openInterest': 5847,
#     'changeinOpenInterest': 44,
#     'pchangeinOpenInterest': 0.7582285024987075,
#     'totalTradedVolume': 38181,
#     'impliedVolatility': 19.6,
#     'lastPrice': 1.45,
#     'change': -0.5999999999999999,
#     'pChange': -29.268292682926827,
#     'totalBuyQuantity': 394800,
#     'totalSellQuantity': 73200,
#     'bidQty': 11150,
#     'bidprice': 1.45,
#     'askQty': 100,
#     'askPrice': 1.55,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18900,
#     'openInterest': 37907,
#     'changeinOpenInterest': -12314,
#     'pchangeinOpenInterest': -24.519623265167958,
#     'totalTradedVolume': 184995,
#     'impliedVolatility': 20.53,
#     'lastPrice': 1.35,
#     'change': -0.6999999999999997,
#     'pChange': -34.14634146341463,
#     'totalBuyQuantity': 1117950,
#     'totalSellQuantity': 165000,
#     'bidQty': 450,
#     'bidprice': 1.35,
#     'askQty': 20100,
#     'askPrice': 1.4,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18950,
#     'openInterest': 2930,
#     'changeinOpenInterest': -631,
#     'pchangeinOpenInterest': -17.71974164560517,
#     'totalTradedVolume': 22705,
#     'impliedVolatility': 21.31,
#     'lastPrice': 1.2,
#     'change': -0.75,
#     'pChange': -38.46153846153847,
#     'totalBuyQuantity': 253050,
#     'totalSellQuantity': 79400,
#     'bidQty': 10850,
#     'bidprice': 1.2,
#     'askQty': 4100,
#     'askPrice': 1.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19000,
#     'openInterest': 115377,
#     'changeinOpenInterest': -49034,
#     'pchangeinOpenInterest': -29.82403853756744,
#     'totalTradedVolume': 538616,
#     'impliedVolatility': 22.27,
#     'lastPrice': 1.15,
#     'change': -0.7000000000000002,
#     'pChange': -37.837837837837846,
#     'totalBuyQuantity': 5609250,
#     'totalSellQuantity': 715800,
#     'bidQty': 329550,
#     'bidprice': 1.1,
#     'askQty': 80700,
#     'askPrice': 1.15,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19050,
#     'openInterest': 2245,
#     'changeinOpenInterest': 10,
#     'pchangeinOpenInterest': 0.44742729306487694,
#     'totalTradedVolume': 16153,
#     'impliedVolatility': 23.58,
#     'lastPrice': 1.25,
#     'change': -0.5,
#     'pChange': -28.57142857142857,
#     'totalBuyQuantity': 171600,
#     'totalSellQuantity': 64550,
#     'bidQty': 300,
#     'bidprice': 1.2,
#     'askQty': 2000,
#     'askPrice': 1.3,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19100,
#     'openInterest': 11398,
#     'changeinOpenInterest': -142,
#     'pchangeinOpenInterest': -1.2305025996533796,
#     'totalTradedVolume': 73324,
#     'impliedVolatility': 24.27,
#     'lastPrice': 1.1,
#     'change': -0.5499999999999998,
#     'pChange': -33.33333333333333,
#     'totalBuyQuantity': 1038300,
#     'totalSellQuantity': 116150,
#     'bidQty': 36100,
#     'bidprice': 1.05,
#     'askQty': 19200,
#     'askPrice': 1.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19150,
#     'openInterest': 889,
#     'changeinOpenInterest': -127,
#     'pchangeinOpenInterest': -12.5,
#     'totalTradedVolume': 10664,
#     'impliedVolatility': 25.18,
#     'lastPrice': 1.05,
#     'change': -0.6499999999999999,
#     'pChange': -38.23529411764706,
#     'totalBuyQuantity': 175650,
#     'totalSellQuantity': 70050,
#     'bidQty': 4700,
#     'bidprice': 1.05,
#     'askQty': 1100,
#     'askPrice': 1.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19200,
#     'openInterest': 43631,
#     'changeinOpenInterest': -28715,
#     'pchangeinOpenInterest': -39.691206148232105,
#     'totalTradedVolume': 152458,
#     'impliedVolatility': 26.21,
#     'lastPrice': 1.05,
#     'change': -0.75,
#     'pChange': -41.666666666666664,
#     'totalBuyQuantity': 1875350,
#     'totalSellQuantity': 160400,
#     'bidQty': 1011100,
#     'bidprice': 1,
#     'askQty': 36450,
#     'askPrice': 1.05,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19250,
#     'openInterest': 521,
#     'changeinOpenInterest': 19,
#     'pchangeinOpenInterest': 3.7848605577689245,
#     'totalTradedVolume': 8448,
#     'impliedVolatility': 27.09,
#     'lastPrice': 1,
#     'change': -0.6499999999999999,
#     'pChange': -39.39393939393939,
#     'totalBuyQuantity': 238400,
#     'totalSellQuantity': 63800,
#     'bidQty': 2550,
#     'bidprice': 1,
#     'askQty': 1800,
#     'askPrice': 1.05,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19300,
#     'openInterest': 6968,
#     'changeinOpenInterest': -536,
#     'pchangeinOpenInterest': -7.142857142857143,
#     'totalTradedVolume': 31530,
#     'impliedVolatility': 27.94,
#     'lastPrice': 0.95,
#     'change': -0.44999999999999996,
#     'pChange': -32.14285714285714,
#     'totalBuyQuantity': 927100,
#     'totalSellQuantity': 70500,
#     'bidQty': 11300,
#     'bidprice': 0.9,
#     'askQty': 6950,
#     'askPrice': 0.95,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19350,
#     'openInterest': 789,
#     'changeinOpenInterest': 330,
#     'pchangeinOpenInterest': 71.89542483660131,
#     'totalTradedVolume': 9183,
#     'impliedVolatility': 28.77,
#     'lastPrice': 0.9,
#     'change': -0.6,
#     'pChange': -40,
#     'totalBuyQuantity': 195300,
#     'totalSellQuantity': 66900,
#     'bidQty': 950,
#     'bidprice': 0.9,
#     'askQty': 1800,
#     'askPrice': 0.95,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19400,
#     'openInterest': 3982,
#     'changeinOpenInterest': 127,
#     'pchangeinOpenInterest': 3.2944228274967573,
#     'totalTradedVolume': 21776,
#     'impliedVolatility': 29.57,
#     'lastPrice': 0.85,
#     'change': -0.5499999999999999,
#     'pChange': -39.285714285714285,
#     'totalBuyQuantity': 984450,
#     'totalSellQuantity': 56900,
#     'bidQty': 10700,
#     'bidprice': 0.85,
#     'askQty': 500,
#     'askPrice': 1.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19450,
#     'openInterest': 433,
#     'changeinOpenInterest': -85,
#     'pchangeinOpenInterest': -16.409266409266408,
#     'totalTradedVolume': 6199,
#     'impliedVolatility': 30.35,
#     'lastPrice': 0.8,
#     'change': -0.6499999999999999,
#     'pChange': -44.82758620689655,
#     'totalBuyQuantity': 153900,
#     'totalSellQuantity': 57900,
#     'bidQty': 20900,
#     'bidprice': 0.8,
#     'askQty': 1800,
#     'askPrice': 0.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19500,
#     'openInterest': 76571,
#     'changeinOpenInterest': -5280,
#     'pchangeinOpenInterest': -6.450745867490928,
#     'totalTradedVolume': 188463,
#     'impliedVolatility': 31.53,
#     'lastPrice': 0.85,
#     'change': -0.5000000000000001,
#     'pChange': -37.03703703703704,
#     'totalBuyQuantity': 2608400,
#     'totalSellQuantity': 455950,
#     'bidQty': 89050,
#     'bidprice': 0.8,
#     'askQty': 25950,
#     'askPrice': 0.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19550,
#     'openInterest': 310,
#     'changeinOpenInterest': 10,
#     'pchangeinOpenInterest': 3.3333333333333335,
#     'totalTradedVolume': 4280,
#     'impliedVolatility': 32.29,
#     'lastPrice': 0.8,
#     'change': -0.44999999999999996,
#     'pChange': -36,
#     'totalBuyQuantity': 87650,
#     'totalSellQuantity': 55250,
#     'bidQty': 3300,
#     'bidprice': 0.8,
#     'askQty': 5350,
#     'askPrice': 0.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19600,
#     'openInterest': 1781,
#     'changeinOpenInterest': 422,
#     'pchangeinOpenInterest': 31.05224429727741,
#     'totalTradedVolume': 9370,
#     'impliedVolatility': 33.25,
#     'lastPrice': 0.8,
#     'change': -0.44999999999999996,
#     'pChange': -36,
#     'totalBuyQuantity': 789950,
#     'totalSellQuantity': 53750,
#     'bidQty': 100,
#     'bidprice': 0.75,
#     'askQty': 1000,
#     'askPrice': 0.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19650,
#     'openInterest': 378,
#     'changeinOpenInterest': -31,
#     'pchangeinOpenInterest': -7.579462102689487,
#     'totalTradedVolume': 1391,
#     'impliedVolatility': 34.2,
#     'lastPrice': 0.8,
#     'change': -0.44999999999999996,
#     'pChange': -36,
#     'totalBuyQuantity': 109100,
#     'totalSellQuantity': 51500,
#     'bidQty': 3550,
#     'bidprice': 0.75,
#     'askQty': 500,
#     'askPrice': 0.8,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19700,
#     'openInterest': 2130,
#     'changeinOpenInterest': -291,
#     'pchangeinOpenInterest': -12.019826517967783,
#     'totalTradedVolume': 8153,
#     'impliedVolatility': 35.15,
#     'lastPrice': 0.8,
#     'change': -0.3999999999999999,
#     'pChange': -33.33333333333333,
#     'totalBuyQuantity': 694150,
#     'totalSellQuantity': 49700,
#     'bidQty': 3600,
#     'bidprice': 0.7,
#     'askQty': 1000,
#     'askPrice': 0.9,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19750,
#     'openInterest': 131,
#     'changeinOpenInterest': -34,
#     'pchangeinOpenInterest': -20.606060606060606,
#     'totalTradedVolume': 1067,
#     'impliedVolatility': 36.1,
#     'lastPrice': 0.8,
#     'change': -0.3999999999999999,
#     'pChange': -33.33333333333333,
#     'totalBuyQuantity': 28700,
#     'totalSellQuantity': 16550,
#     'bidQty': 4500,
#     'bidprice': 0.75,
#     'askQty': 2150,
#     'askPrice': 0.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19800,
#     'openInterest': 2157,
#     'changeinOpenInterest': -949,
#     'pchangeinOpenInterest': -30.553766902768835,
#     'totalTradedVolume': 8214,
#     'impliedVolatility': 36.79,
#     'lastPrice': 0.75,
#     'change': -0.3500000000000001,
#     'pChange': -31.818181818181824,
#     'totalBuyQuantity': 452400,
#     'totalSellQuantity': 60950,
#     'bidQty': 1650,
#     'bidprice': 0.7,
#     'askQty': 2900,
#     'askPrice': 0.75,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19850,
#     'openInterest': 277,
#     'changeinOpenInterest': -32,
#     'pchangeinOpenInterest': -10.35598705501618,
#     'totalTradedVolume': 1216,
#     'impliedVolatility': 37.97,
#     'lastPrice': 0.8,
#     'change': -0.19999999999999996,
#     'pChange': -19.999999999999996,
#     'totalBuyQuantity': 23500,
#     'totalSellQuantity': 41450,
#     'bidQty': 1100,
#     'bidprice': 0.75,
#     'askQty': 650,
#     'askPrice': 0.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19900,
#     'openInterest': 4299,
#     'changeinOpenInterest': -3638,
#     'pchangeinOpenInterest': -45.83595817059342,
#     'totalTradedVolume': 9798,
#     'impliedVolatility': 38.37,
#     'lastPrice': 0.7,
#     'change': -0.30000000000000004,
#     'pChange': -30.000000000000004,
#     'totalBuyQuantity': 449750,
#     'totalSellQuantity': 76350,
#     'bidQty': 950,
#     'bidprice': 0.7,
#     'askQty': 18550,
#     'askPrice': 0.75,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19950,
#     'openInterest': 191,
#     'changeinOpenInterest': -72,
#     'pchangeinOpenInterest': -27.376425855513308,
#     'totalTradedVolume': 1177,
#     'impliedVolatility': 39.56,
#     'lastPrice': 0.75,
#     'change': -0.30000000000000004,
#     'pChange': -28.571428571428577,
#     'totalBuyQuantity': 18700,
#     'totalSellQuantity': 40250,
#     'bidQty': 3600,
#     'bidprice': 0.7,
#     'askQty': 2000,
#     'askPrice': 0.8,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20000,
#     'openInterest': 51040,
#     'changeinOpenInterest': -66321,
#     'pchangeinOpenInterest': -56.51025468426479,
#     'totalTradedVolume': 170793,
#     'impliedVolatility': 39.59,
#     'lastPrice': 0.6,
#     'change': -0.35,
#     'pChange': -36.84210526315789,
#     'totalBuyQuantity': 1743600,
#     'totalSellQuantity': 313900,
#     'bidQty': 251150,
#     'bidprice': 0.6,
#     'askQty': 125500,
#     'askPrice': 0.7,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20050,
#     'openInterest': 409,
#     'changeinOpenInterest': -605,
#     'pchangeinOpenInterest': -59.6646942800789,
#     'totalTradedVolume': 3089,
#     'impliedVolatility': 41.93,
#     'lastPrice': 0.85,
#     'change': -0.050000000000000044,
#     'pChange': -5.55555555555556,
#     'totalBuyQuantity': 20350,
#     'totalSellQuantity': 35050,
#     'bidQty': 300,
#     'bidprice': 0.8,
#     'askQty': 50,
#     'askPrice': 1.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20100,
#     'openInterest': 1684,
#     'changeinOpenInterest': -1765,
#     'pchangeinOpenInterest': -51.17425340678457,
#     'totalTradedVolume': 8706,
#     'impliedVolatility': 42.58,
#     'lastPrice': 0.8,
#     'change': -0.09999999999999998,
#     'pChange': -11.111111111111107,
#     'totalBuyQuantity': 207200,
#     'totalSellQuantity': 59100,
#     'bidQty': 50,
#     'bidprice': 0.75,
#     'askQty': 500,
#     'askPrice': 0.8,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20150,
#     'openInterest': 198,
#     'changeinOpenInterest': -66,
#     'pchangeinOpenInterest': -25,
#     'totalTradedVolume': 742,
#     'impliedVolatility': 43.2,
#     'lastPrice': 0.75,
#     'change': -0.25,
#     'pChange': -25,
#     'totalBuyQuantity': 21450,
#     'totalSellQuantity': 31300,
#     'bidQty': 3250,
#     'bidprice': 0.65,
#     'askQty': 750,
#     'askPrice': 1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20200,
#     'openInterest': 3629,
#     'changeinOpenInterest': -827,
#     'pchangeinOpenInterest': -18.559245960502693,
#     'totalTradedVolume': 5272,
#     'impliedVolatility': 43.48,
#     'lastPrice': 0.65,
#     'change': -0.25,
#     'pChange': -27.77777777777778,
#     'totalBuyQuantity': 220150,
#     'totalSellQuantity': 72450,
#     'bidQty': 7700,
#     'bidprice': 0.65,
#     'askQty': 3000,
#     'askPrice': 0.8,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20250,
#     'openInterest': 542,
#     'changeinOpenInterest': 127,
#     'pchangeinOpenInterest': 30.602409638554217,
#     'totalTradedVolume': 736,
#     'impliedVolatility': 44.99,
#     'lastPrice': 0.75,
#     'change': -0.19999999999999996,
#     'pChange': -21.052631578947363,
#     'totalBuyQuantity': 24400,
#     'totalSellQuantity': 33700,
#     'bidQty': 4400,
#     'bidprice': 0.75,
#     'askQty': 250,
#     'askPrice': 1.05,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20300,
#     'openInterest': 13479,
#     'changeinOpenInterest': -410,
#     'pchangeinOpenInterest': -2.9519763841889266,
#     'totalTradedVolume': 14238,
#     'impliedVolatility': 45.24,
#     'lastPrice': 0.65,
#     'change': -0.25,
#     'pChange': -27.77777777777778,
#     'totalBuyQuantity': 412300,
#     'totalSellQuantity': 102150,
#     'bidQty': 500,
#     'bidprice': 0.65,
#     'askQty': 2200,
#     'askPrice': 0.75,
#     'underlyingValue': 18101.2}],
#   'PE': [{'strikePrice': 16300,
#     'openInterest': 30198,
#     'changeinOpenInterest': 2079,
#     'pchangeinOpenInterest': 7.393577296489918,
#     'totalTradedVolume': 75798,
#     'impliedVolatility': 44.72,
#     'lastPrice': 1,
#     'change': 0.15000000000000002,
#     'pChange': 17.647058823529417,
#     'totalBuyQuantity': 690950,
#     'totalSellQuantity': 61800,
#     'bidQty': 5450,
#     'bidprice': 0.95,
#     'askQty': 900,
#     'askPrice': 1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16350,
#     'openInterest': 331,
#     'changeinOpenInterest': -500,
#     'pchangeinOpenInterest': -60.16847172081829,
#     'totalTradedVolume': 11846,
#     'impliedVolatility': 44,
#     'lastPrice': 1.1,
#     'change': 0.15000000000000013,
#     'pChange': 15.789473684210542,
#     'totalBuyQuantity': 25850,
#     'totalSellQuantity': 3450,
#     'bidQty': 800,
#     'bidprice': 1,
#     'askQty': 50,
#     'askPrice': 1.15,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16400,
#     'openInterest': 1678,
#     'changeinOpenInterest': -119,
#     'pchangeinOpenInterest': -6.622148024485253,
#     'totalTradedVolume': 17395,
#     'impliedVolatility': 42.38,
#     'lastPrice': 1,
#     'change': -0.10000000000000009,
#     'pChange': -9.090909090909099,
#     'totalBuyQuantity': 208650,
#     'totalSellQuantity': 12000,
#     'bidQty': 900,
#     'bidprice': 0.95,
#     'askQty': 2800,
#     'askPrice': 1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16450,
#     'openInterest': 287,
#     'changeinOpenInterest': -862,
#     'pchangeinOpenInterest': -75.02175805047868,
#     'totalTradedVolume': 7356,
#     'impliedVolatility': 41.22,
#     'lastPrice': 1,
#     'change': -0.050000000000000044,
#     'pChange': -4.761904761904765,
#     'totalBuyQuantity': 131100,
#     'totalSellQuantity': 2950,
#     'bidQty': 50,
#     'bidprice': 0.9,
#     'askQty': 1000,
#     'askPrice': 1.4,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16500,
#     'openInterest': 72449,
#     'changeinOpenInterest': -1540,
#     'pchangeinOpenInterest': -2.081390476962792,
#     'totalTradedVolume': 140588,
#     'impliedVolatility': 40.48,
#     'lastPrice': 1.1,
#     'change': -0.1499999999999999,
#     'pChange': -11.999999999999993,
#     'totalBuyQuantity': 1056400,
#     'totalSellQuantity': 35350,
#     'bidQty': 4350,
#     'bidprice': 1.1,
#     'askQty': 7350,
#     'askPrice': 1.2,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16550,
#     'openInterest': 655,
#     'changeinOpenInterest': -1569,
#     'pchangeinOpenInterest': -70.54856115107914,
#     'totalTradedVolume': 8084,
#     'impliedVolatility': 39.5,
#     'lastPrice': 1.15,
#     'change': 0.04999999999999982,
#     'pChange': 4.545454545454529,
#     'totalBuyQuantity': 129100,
#     'totalSellQuantity': 3000,
#     'bidQty': 1800,
#     'bidprice': 0.9,
#     'askQty': 100,
#     'askPrice': 1.15,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16600,
#     'openInterest': 4635,
#     'changeinOpenInterest': -3151,
#     'pchangeinOpenInterest': -40.47007449267917,
#     'totalTradedVolume': 29205,
#     'impliedVolatility': 38.32,
#     'lastPrice': 1.15,
#     'change': -0.050000000000000044,
#     'pChange': -4.1666666666666705,
#     'totalBuyQuantity': 295850,
#     'totalSellQuantity': 13050,
#     'bidQty': 11000,
#     'bidprice': 0.9,
#     'askQty': 2250,
#     'askPrice': 1.15,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16650,
#     'openInterest': 440,
#     'changeinOpenInterest': -584,
#     'pchangeinOpenInterest': -57.03125,
#     'totalTradedVolume': 15518,
#     'impliedVolatility': 36.77,
#     'lastPrice': 1.05,
#     'change': -0.25,
#     'pChange': -19.23076923076923,
#     'totalBuyQuantity': 127500,
#     'totalSellQuantity': 3700,
#     'bidQty': 3650,
#     'bidprice': 0.9,
#     'askQty': 1800,
#     'askPrice': 1.25,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16700,
#     'openInterest': 8121,
#     'changeinOpenInterest': -4199,
#     'pchangeinOpenInterest': -34.08279220779221,
#     'totalTradedVolume': 72101,
#     'impliedVolatility': 35.97,
#     'lastPrice': 1.15,
#     'change': -0.25,
#     'pChange': -17.857142857142858,
#     'totalBuyQuantity': 221950,
#     'totalSellQuantity': 8500,
#     'bidQty': 850,
#     'bidprice': 1.05,
#     'askQty': 1300,
#     'askPrice': 1.3,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16750,
#     'openInterest': 1995,
#     'changeinOpenInterest': 272,
#     'pchangeinOpenInterest': 15.786419036564132,
#     'totalTradedVolume': 21123,
#     'impliedVolatility': 34.96,
#     'lastPrice': 1.2,
#     'change': -0.15000000000000013,
#     'pChange': -11.11111111111112,
#     'totalBuyQuantity': 201500,
#     'totalSellQuantity': 5400,
#     'bidQty': 1550,
#     'bidprice': 1.05,
#     'askQty': 650,
#     'askPrice': 1.2,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16800,
#     'openInterest': 17403,
#     'changeinOpenInterest': 1528,
#     'pchangeinOpenInterest': 9.625196850393701,
#     'totalTradedVolume': 125845,
#     'impliedVolatility': 34.4,
#     'lastPrice': 1.4,
#     'change': -0.10000000000000009,
#     'pChange': -6.666666666666672,
#     'totalBuyQuantity': 569100,
#     'totalSellQuantity': 35900,
#     'bidQty': 42900,
#     'bidprice': 1.05,
#     'askQty': 50,
#     'askPrice': 1.4,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16850,
#     'openInterest': 1595,
#     'changeinOpenInterest': 162,
#     'pchangeinOpenInterest': 11.304954640614095,
#     'totalTradedVolume': 26025,
#     'impliedVolatility': 32.75,
#     'lastPrice': 1.25,
#     'change': -0.30000000000000004,
#     'pChange': -19.35483870967742,
#     'totalBuyQuantity': 181500,
#     'totalSellQuantity': 2700,
#     'bidQty': 17950,
#     'bidprice': 1.1,
#     'askQty': 500,
#     'askPrice': 1.25,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16900,
#     'openInterest': 15834,
#     'changeinOpenInterest': 3279,
#     'pchangeinOpenInterest': 26.117084826762245,
#     'totalTradedVolume': 107635,
#     'impliedVolatility': 31.41,
#     'lastPrice': 1.2,
#     'change': -0.40000000000000013,
#     'pChange': -25.000000000000007,
#     'totalBuyQuantity': 512650,
#     'totalSellQuantity': 17650,
#     'bidQty': 21450,
#     'bidprice': 1.15,
#     'askQty': 100,
#     'askPrice': 1.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16950,
#     'openInterest': 2591,
#     'changeinOpenInterest': 314,
#     'pchangeinOpenInterest': 13.790074659639878,
#     'totalTradedVolume': 37331,
#     'impliedVolatility': 30.38,
#     'lastPrice': 1.25,
#     'change': -0.5,
#     'pChange': -28.57142857142857,
#     'totalBuyQuantity': 199650,
#     'totalSellQuantity': 6850,
#     'bidQty': 12450,
#     'bidprice': 1.15,
#     'askQty': 400,
#     'askPrice': 1.45,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17000,
#     'openInterest': 86517,
#     'changeinOpenInterest': -2009,
#     'pchangeinOpenInterest': -2.2693897837923322,
#     'totalTradedVolume': 477527,
#     'impliedVolatility': 29.59,
#     'lastPrice': 1.4,
#     'change': -0.55,
#     'pChange': -28.20512820512821,
#     'totalBuyQuantity': 2167300,
#     'totalSellQuantity': 60150,
#     'bidQty': 2800,
#     'bidprice': 1.4,
#     'askQty': 450,
#     'askPrice': 1.6,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17050,
#     'openInterest': 4341,
#     'changeinOpenInterest': 1332,
#     'pchangeinOpenInterest': 44.267198404785645,
#     'totalTradedVolume': 45539,
#     'impliedVolatility': 28.39,
#     'lastPrice': 1.4,
#     'change': -0.7000000000000002,
#     'pChange': -33.33333333333334,
#     'totalBuyQuantity': 374600,
#     'totalSellQuantity': 14750,
#     'bidQty': 2150,
#     'bidprice': 1.4,
#     'askQty': 3500,
#     'askPrice': 2,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17100,
#     'openInterest': 30510,
#     'changeinOpenInterest': -79,
#     'pchangeinOpenInterest': -0.25826277419987576,
#     'totalTradedVolume': 208007,
#     'impliedVolatility': 27.53,
#     'lastPrice': 1.55,
#     'change': -0.8,
#     'pChange': -34.04255319148936,
#     'totalBuyQuantity': 360100,
#     'totalSellQuantity': 22500,
#     'bidQty': 1600,
#     'bidprice': 1.5,
#     'askQty': 50,
#     'askPrice': 1.7,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17150,
#     'openInterest': 4911,
#     'changeinOpenInterest': -2111,
#     'pchangeinOpenInterest': -30.062660210766165,
#     'totalTradedVolume': 58942,
#     'impliedVolatility': 26.42,
#     'lastPrice': 1.6,
#     'change': -1,
#     'pChange': -38.46153846153846,
#     'totalBuyQuantity': 125450,
#     'totalSellQuantity': 16900,
#     'bidQty': 800,
#     'bidprice': 1.5,
#     'askQty': 50,
#     'askPrice': 1.85,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17200,
#     'openInterest': 40246,
#     'changeinOpenInterest': -688,
#     'pchangeinOpenInterest': -1.6807543851077344,
#     'totalTradedVolume': 408388,
#     'impliedVolatility': 25.59,
#     'lastPrice': 1.8,
#     'change': -1.0999999999999999,
#     'pChange': -37.93103448275862,
#     'totalBuyQuantity': 619500,
#     'totalSellQuantity': 109100,
#     'bidQty': 1500,
#     'bidprice': 1.65,
#     'askQty': 6650,
#     'askPrice': 1.8,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17250,
#     'openInterest': 10370,
#     'changeinOpenInterest': -4321,
#     'pchangeinOpenInterest': -29.412565516302497,
#     'totalTradedVolume': 95015,
#     'impliedVolatility': 24.15,
#     'lastPrice': 1.7,
#     'change': -1.7,
#     'pChange': -50,
#     'totalBuyQuantity': 195000,
#     'totalSellQuantity': 23200,
#     'bidQty': 100,
#     'bidprice': 1.7,
#     'askQty': 200,
#     'askPrice': 2.6,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17300,
#     'openInterest': 40193,
#     'changeinOpenInterest': -13754,
#     'pchangeinOpenInterest': -25.49539362707843,
#     'totalTradedVolume': 419747,
#     'impliedVolatility': 23.59,
#     'lastPrice': 2.1,
#     'change': -2.15,
#     'pChange': -50.588235294117645,
#     'totalBuyQuantity': 102000,
#     'totalSellQuantity': 47100,
#     'bidQty': 500,
#     'bidprice': 2.05,
#     'askQty': 1250,
#     'askPrice': 2.1,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17350,
#     'openInterest': 13568,
#     'changeinOpenInterest': -25181,
#     'pchangeinOpenInterest': -64.98490283620222,
#     'totalTradedVolume': 193195,
#     'impliedVolatility': 22.54,
#     'lastPrice': 2.25,
#     'change': -2.9000000000000004,
#     'pChange': -56.31067961165049,
#     'totalBuyQuantity': 46900,
#     'totalSellQuantity': 24650,
#     'bidQty': 50,
#     'bidprice': 2.1,
#     'askQty': 500,
#     'askPrice': 2.3,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17400,
#     'openInterest': 55177,
#     'changeinOpenInterest': -2989,
#     'pchangeinOpenInterest': -5.13874084516728,
#     'totalTradedVolume': 548155,
#     'impliedVolatility': 21.39,
#     'lastPrice': 2.35,
#     'change': -4.6,
#     'pChange': -66.18705035971222,
#     'totalBuyQuantity': 236900,
#     'totalSellQuantity': 46850,
#     'bidQty': 200,
#     'bidprice': 2.25,
#     'askQty': 800,
#     'askPrice': 2.35,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17450,
#     'openInterest': 24993,
#     'changeinOpenInterest': -3683,
#     'pchangeinOpenInterest': -12.84349281629237,
#     'totalTradedVolume': 258458,
#     'impliedVolatility': 20.15,
#     'lastPrice': 2.4,
#     'change': -6.65,
#     'pChange': -73.48066298342542,
#     'totalBuyQuantity': 49650,
# ...
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 3300,
#     'totalSellQuantity': 0,
#     'bidQty': 250,
#     'bidprice': 38.95,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 22000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 290.75,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 23000,
#     'openInterest': 7,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 2501,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2000,
#     'totalSellQuantity': 50,
#     'bidQty': 50,
#     'bidprice': 3095,
#     'askQty': 50,
#     'askPrice': 3120,
#     'underlyingValue': 18101.2}]},
#  '24-Jun-2027': {'CE': ['-',
#    {'strikePrice': 14000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 9360,
#     'underlyingValue': 18101.2},
#    '-',
#    '-',
#    '-',
#    {'strikePrice': 18000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 7500,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 7090,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 6699,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 21000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 6320,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 22000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 5960,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 23000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 5615,
#     'underlyingValue': 18101.2}],
#   'PE': [{'strikePrice': 13000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 1.75,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 14000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 2.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 15000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 9.75,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 5.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 9.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2800,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 19.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2800,
#     'totalSellQuantity': 0,
#     'bidQty': 250,
#     'bidprice': 10.15,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2800,
#     'totalSellQuantity': 0,
#     'bidQty': 250,
#     'bidprice': 15.2,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 21000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2800,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 23.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 22000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 135.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 23000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 390.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2}]},
#  '30-Dec-2027': {'CE': ['-',
#    '-',
#    {'strikePrice': 15000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 9280,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 8830,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 8390,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 7980,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 7580,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 7200,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 21000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 6840,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 22000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 6490,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 23000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 0,
#     'totalSellQuantity': 50,
#     'bidQty': 0,
#     'bidprice': 0,
#     'askQty': 50,
#     'askPrice': 6150,
#     'underlyingValue': 18101.2}],
#   'PE': [{'strikePrice': 13000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2600,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 1.75,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 14000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2600,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 2.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 15000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2600,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 3.75,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 16000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2600,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 5.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 17000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2600,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 10.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 18000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2650,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 510.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 19000,
#     'openInterest': 10,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 1720,
#     'change': -11.049999999999955,
#     'pChange': -0.6383408913665091,
#     'totalBuyQuantity': 3250,
#     'totalSellQuantity': 350,
#     'bidQty': 50,
#     'bidprice': 1496.05,
#     'askQty': 300,
#     'askPrice': 1999.95,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 20000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2850,
#     'totalSellQuantity': 0,
#     'bidQty': 250,
#     'bidprice': 8.25,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 21000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2850,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 12.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 22000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2850,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 23.05,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2},
#    {'strikePrice': 23000,
#     'openInterest': 0,
#     'changeinOpenInterest': 0,
#     'pchangeinOpenInterest': 0,
#     'totalTradedVolume': 0,
#     'impliedVolatility': 0,
#     'lastPrice': 0,
#     'change': 0,
#     'pChange': 0,
#     'totalBuyQuantity': 2550,
#     'totalSellQuantity': 0,
#     'bidQty': 750,
#     'bidprice': 199.3,
#     'askQty': 0,
#     'askPrice': 0,
#     'underlyingValue': 18101.2}]}}

# %%
oc_data_dt=oc_data['28-Dec-2023']
type(oc_data_dt)
# Out:
# dict

# %%
CE=list(oc_data_dt['CE'])
PE=list(oc_data_dt['PE'])
CE
# Out:
# [{'strikePrice': 11000,
#   'openInterest': 14,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 1,
#   'impliedVolatility': 0,
#   'lastPrice': 7300,
#   'change': 150.05000000000018,
#   'pChange': 2.098616074238284,
#   'totalBuyQuantity': 300,
#   'totalSellQuantity': 100,
#   'bidQty': 50,
#   'bidprice': 7151.1,
#   'askQty': 50,
#   'askPrice': 7372.1,
#   'underlyingValue': 18101.2},
#  '-',
#  '-',
#  {'strikePrice': 13000,
#   'openInterest': 5,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 5401,
#   'change': 0,
#   'pChange': 0,
#   'totalBuyQuantity': 250,
#   'totalSellQuantity': 0,
#   'bidQty': 250,
#   'bidprice': 4798.25,
#   'askQty': 0,
#   'askPrice': 0,
#   'underlyingValue': 18101.2},
#  '-',
#  {'strikePrice': 14000,
#   'openInterest': 16,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 4440,
#   'change': 0,
#   'pChange': 0,
#   'totalBuyQuantity': 300,
#   'totalSellQuantity': 200,
#   'bidQty': 300,
#   'bidprice': 3840.25,
#   'askQty': 100,
#   'askPrice': 5830.6,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 14500,
#   'openInterest': 21.5,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 1,
#   'impliedVolatility': 0,
#   'lastPrice': 4000.05,
#   'change': -99.94999999999982,
#   'pChange': -2.437804878048776,
#   'totalBuyQuantity': 500,
#   'totalSellQuantity': 100,
#   'bidQty': 100,
#   'bidprice': 4001,
#   'askQty': 50,
#   'askPrice': 5446.85,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 15000,
#   'openInterest': 395,
#   'changeinOpenInterest': 1,
#   'pchangeinOpenInterest': 0.25380710659898476,
#   'totalTradedVolume': 1,
#   'impliedVolatility': 0,
#   'lastPrice': 3630,
#   'change': 103.15000000000009,
#   'pChange': 2.9247061825708522,
#   'totalBuyQuantity': 800,
#   'totalSellQuantity': 4950,
#   'bidQty': 50,
#   'bidprice': 3624.8,
#   'askQty': 100,
#   'askPrice': 3710,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 15500,
#   'openInterest': 57,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 3350,
#   'change': 0,
#   'pChange': 0,
#   'totalBuyQuantity': 100,
#   'totalSellQuantity': 200,
#   'bidQty': 50,
#   'bidprice': 2465.2,
#   'askQty': 50,
#   'askPrice': 4710.05,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 16000,
#   'openInterest': 514,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 1,
#   'impliedVolatility': 0,
#   'lastPrice': 2932.45,
#   'change': 273.14999999999964,
#   'pChange': 10.271500018801925,
#   'totalBuyQuantity': 2450,
#   'totalSellQuantity': 1550,
#   'bidQty': 50,
#   'bidprice': 2729.65,
#   'askQty': 50,
#   'askPrice': 2993.2,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 16500,
#   'openInterest': 54,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 2560,
#   'change': 0,
#   'pChange': 0,
#   'totalBuyQuantity': 1300,
#   'totalSellQuantity': 200,
#   'bidQty': 1300,
#   'bidprice': 1659.25,
#   'askQty': 50,
#   'askPrice': 3499.55,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 17000,
#   'openInterest': 772,
#   'changeinOpenInterest': 4,
#   'pchangeinOpenInterest': 0.5208333333333334,
#   'totalTradedVolume': 13,
#   'impliedVolatility': 0,
#   'lastPrice': 2140,
#   'change': 165,
#   'pChange': 8.354430379746836,
#   'totalBuyQuantity': 3550,
#   'totalSellQuantity': 450,
#   'bidQty': 50,
#   'bidprice': 2012.4,
#   'askQty': 100,
#   'askPrice': 2174.35,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 17500,
#   'openInterest': 133,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 2,
#   'impliedVolatility': 0,
#   'lastPrice': 1771.6,
#   'change': 119.59999999999991,
#   'pChange': 7.239709443099268,
#   'totalBuyQuantity': 2250,
#   'totalSellQuantity': 100,
#   'bidQty': 50,
#   'bidprice': 1763.45,
#   'askQty': 50,
#   'askPrice': 1829.6,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 18000,
#   'openInterest': 3955.5,
#   'changeinOpenInterest': 60,
#   'pchangeinOpenInterest': 1.5402387370042356,
#   'totalTradedVolume': 453,
#   'impliedVolatility': 0,
#   'lastPrice': 1496.05,
#   'change': 110.04999999999995,
#   'pChange': 7.940115440115438,
#   'totalBuyQuantity': 6950,
#   'totalSellQuantity': 900,
#   'bidQty': 50,
#   'bidprice': 1485.45,
#   'askQty': 50,
#   'askPrice': 1505.95,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 18500,
#   'openInterest': 527,
#   'changeinOpenInterest': 12,
#   'pchangeinOpenInterest': 2.3300970873786406,
#   'totalTradedVolume': 151,
#   'impliedVolatility': 0,
#   'lastPrice': 1197,
#   'change': 101.45000000000005,
#   'pChange': 9.260188946191414,
#   'totalBuyQuantity': 7350,
#   'totalSellQuantity': 350,
#   'bidQty': 50,
#   'bidprice': 1182.6,
#   'askQty': 50,
#   'askPrice': 1206.25,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 19000,
#   'openInterest': 3722,
#   'changeinOpenInterest': 155,
#   'pchangeinOpenInterest': 4.345388281469021,
#   'totalTradedVolume': 504,
#   'impliedVolatility': 4.82,
#   'lastPrice': 920.2,
#   'change': 83.85000000000002,
#   'pChange': 10.025706940874038,
#   'totalBuyQuantity': 11750,
#   'totalSellQuantity': 1900,
#   'bidQty': 50,
#   'bidprice': 920.25,
#   'askQty': 150,
#   'askPrice': 932,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 20000,
#   'openInterest': 4071,
#   'changeinOpenInterest': 237,
#   'pchangeinOpenInterest': 6.181533646322379,
#   'totalTradedVolume': 635,
#   'impliedVolatility': 7.15,
#   'lastPrice': 481.05,
#   'change': 52.650000000000034,
#   'pChange': 12.289915966386564,
#   'totalBuyQuantity': 14350,
#   'totalSellQuantity': 1850,
#   'bidQty': 50,
#   'bidprice': 481,
#   'askQty': 50,
#   'askPrice': 486.5,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 21000,
#   'openInterest': 2612,
#   'changeinOpenInterest': 191,
#   'pchangeinOpenInterest': 7.889301941346551,
#   'totalTradedVolume': 739,
#   'impliedVolatility': 7.77,
#   'lastPrice': 210,
#   'change': 30.849999999999994,
#   'pChange': 17.220206530840073,
#   'totalBuyQuantity': 18250,
#   'totalSellQuantity': 850,
#   'bidQty': 100,
#   'bidprice': 205,
#   'askQty': 50,
#   'askPrice': 210,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 22000,
#   'openInterest': 1242,
#   'changeinOpenInterest': 11,
#   'pchangeinOpenInterest': 0.8935824532900081,
#   'totalTradedVolume': 36,
#   'impliedVolatility': 8.3,
#   'lastPrice': 86.15,
#   'change': 8.75,
#   'pChange': 11.304909560723514,
#   'totalBuyQuantity': 4000,
#   'totalSellQuantity': 2150,
#   'bidQty': 100,
#   'bidprice': 82,
#   'askQty': 50,
#   'askPrice': 86,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 23000,
#   'openInterest': 602,
#   'changeinOpenInterest': 9,
#   'pchangeinOpenInterest': 1.5177065767284992,
#   'totalTradedVolume': 64,
#   'impliedVolatility': 9.36,
#   'lastPrice': 46.5,
#   'change': -1.1000000000000014,
#   'pChange': -2.310924369747902,
#   'totalBuyQuantity': 9400,
#   'totalSellQuantity': 3050,
#   'bidQty': 500,
#   'bidprice': 45.5,
#   'askQty': 50,
#   'askPrice': 48,
#   'underlyingValue': 18101.2},
#  {'strikePrice': 24000,
#   'openInterest': 38,
#   'changeinOpenInterest': 0,
#   'pchangeinOpenInterest': 0,
#   'totalTradedVolume': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 36.5,
#   'change': 0,
#   'pChange': 0,
#   'totalBuyQuantity': 700,
#   'totalSellQuantity': 2000,
#   'bidQty': 50,
#   'bidprice': 25.1,
#   'askQty': 50,
#   'askPrice': 60,
#   'underlyingValue': 18101.2}]
