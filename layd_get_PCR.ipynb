# %%
import json
import requests
import pandas as pd

# %%
url = 'https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY'
headers = {
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
    'accept-encoding' : 'gzip, deflate, br',
    'accept-language' : 'en-US,en;q=0.9'
}
response = requests.get(url, headers=headers).content

# %%
data = json.loads(response.decode('utf-8'))
data
# Out:
# {'records': {'expiryDates': ['20-Oct-2022',
#    '27-Oct-2022',
#    '03-Nov-2022',
#    '10-Nov-2022',
#    '17-Nov-2022',
#    '24-Nov-2022',
#    '01-Dec-2022',
#    '08-Dec-2022',
#    '15-Dec-2022',
#    '29-Dec-2022',
#    '30-Mar-2023',
#    '29-Jun-2023',
#    '28-Sep-2023',
#    '28-Dec-2023',
#    '27-Jun-2024',
#    '26-Dec-2024',
#    '26-Jun-2025',
#    '24-Dec-2025',
#    '25-Jun-2026',
#    '31-Dec-2026',
#    '24-Jun-2027'],
#   'data': [{'strikePrice': 7500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 7500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE7500.00',
#      'openInterest': 53,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9600,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 8500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 8500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE8500.00',
#      'openInterest': 2253,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 10400,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 1.5,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 8700,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 8700,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE8700.00',
#      'openInterest': 2250.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3550,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 9000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 9000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE9000.00',
#      'openInterest': 7657.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 14550,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 9000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 9000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-09-2023PE9000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 9500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 9500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE9500.00',
#      'openInterest': 2334.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3200,
#      'totalSellQuantity': 0,
#      'bidQty': 150,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 9700,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 9700,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE9700.00',
#      'openInterest': 61.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 0.95,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 9900,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 9900,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE9900.00',
#      'openInterest': 0.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 10000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 10000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-09-2023PE10000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 10000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 10000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE10000.00',
#      'openInterest': 4547,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8450,
#      'totalSellQuantity': 0,
#      'bidQty': 6050,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 10000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 10000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE10000.00',
#      'openInterest': 1754,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 100,
#      'totalSellQuantity': 0,
#      'bidQty': 100,
#      'bidprice': 4.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 10500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 10500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE10500.00',
#      'openInterest': 3004.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 10500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 10500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE10500.00',
#      'openInterest': 6167.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6400,
#      'totalSellQuantity': 0,
#      'bidQty': 4000,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 10900,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 10900,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE10900.00',
#      'openInterest': 1.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-09-2023PE11000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '31-Dec-2026',
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '31-Dec-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY31-12-2026PE11000.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1100,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 150,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY30-03-2023PE11000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6900,
#      'totalSellQuantity': 0,
#      'bidQty': 6900,
#      'bidprice': 3.6,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 11000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022CE11000.00',
#      'openInterest': 473,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 0,
#      'lastPrice': 6300,
#      'change': 327,
#      'pChange': 5.474635861376194,
#      'totalBuyQuantity': 3350,
#      'totalSellQuantity': 1100,
#      'bidQty': 50,
#      'bidprice': 6237.15,
#      'askQty': 50,
#      'askPrice': 6305.85,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11000.00',
#      'openInterest': 1952.5,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 0.05124263387138099,
#      'totalTradedVolume': 44,
#      'impliedVolatility': 45.28,
#      'lastPrice': 10.5,
#      'change': -0.25,
#      'pChange': -2.3255813953488373,
#      'totalBuyQuantity': 20850,
#      'totalSellQuantity': 7550,
#      'bidQty': 150,
#      'bidprice': 10.1,
#      'askQty': 150,
#      'askPrice': 10.55,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '28-Dec-2023',
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023PE11000.00',
#      'openInterest': 7.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1150,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 70,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 11000,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023CE11000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 50,
#      'totalSellQuantity': 50,
#      'bidQty': 50,
#      'bidprice': 6000,
#      'askQty': 50,
#      'askPrice': 7900,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '29-Jun-2023',
#     'CE': {'strikePrice': 11000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023CE11000.00',
#      'openInterest': 298.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 50,
#      'totalSellQuantity': 50,
#      'bidQty': 50,
#      'bidprice': 6000,
#      'askQty': 50,
#      'askPrice': 7579,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE11000.00',
#      'openInterest': 5631,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 50,
#      'bidQty': 750,
#      'bidprice': 3.4,
#      'askQty': 50,
#      'askPrice': 20.6,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11000,
#     'expiryDate': '24-Dec-2025',
#     'PE': {'strikePrice': 11000,
#      'expiryDate': '24-Dec-2025',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY24-12-2025PE11000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11100,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11100,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11100.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11200,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11200,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11200.00',
#      'openInterest': 12,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11300,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11300,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11300.00',
#      'openInterest': 33,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3550,
#      'totalSellQuantity': 0,
#      'bidQty': 2800,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11400,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11400,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11400.00',
#      'openInterest': 4.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 11500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE11500.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11500,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 11500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022CE11500.00',
#      'openInterest': 86,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 1.1764705882352942,
#      'totalTradedVolume': 20,
#      'impliedVolatility': 0,
#      'lastPrice': 5779,
#      'change': 231.64999999999964,
#      'pChange': 4.175867756676604,
#      'totalBuyQuantity': 4550,
#      'totalSellQuantity': 1350,
#      'bidQty': 100,
#      'bidprice': 5702.45,
#      'askQty': 100,
#      'askPrice': 5962.85,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 11500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11500.00',
#      'openInterest': 146.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 45200,
#      'totalSellQuantity': 0,
#      'bidQty': 45050,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11600,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11600,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11600.00',
#      'openInterest': 53,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11700,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11700,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11700.00',
#      'openInterest': 18,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11800,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11800,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11800.00',
#      'openInterest': 61.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2350,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11900,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 11900,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE11900.00',
#      'openInterest': 140,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 850,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 11900,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 11900,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE11900.00',
#      'openInterest': 14,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1050,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 11.85,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12000.00',
#      'openInterest': 2898.5,
#      'changeinOpenInterest': 5,
#      'pchangeinOpenInterest': 0.17280110592707792,
#      'totalTradedVolume': 37,
#      'impliedVolatility': 38.93,
#      'lastPrice': 12.6,
#      'change': -1.5999999999999996,
#      'pChange': -11.267605633802814,
#      'totalBuyQuantity': 18100,
#      'totalSellQuantity': 1850,
#      'bidQty': 250,
#      'bidprice': 12,
#      'askQty': 600,
#      'askPrice': 12.95,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 12000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022CE12000.00',
#      'openInterest': 165,
#      'changeinOpenInterest': 9,
#      'pchangeinOpenInterest': 5.769230769230769,
#      'totalTradedVolume': 11,
#      'impliedVolatility': 0,
#      'lastPrice': 5276,
#      'change': 265.9499999999998,
#      'pChange': 5.308330256185064,
#      'totalBuyQuantity': 2300,
#      'totalSellQuantity': 1500,
#      'bidQty': 50,
#      'bidprice': 5266.15,
#      'askQty': 250,
#      'askPrice': 5313.85,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '24-Dec-2025',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '24-Dec-2025',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY24-12-2025PE12000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 850,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 1.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '25-Jun-2026',
#     'CE': {'strikePrice': 12000,
#      'expiryDate': '25-Jun-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY25-06-2026CE12000.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 0,
#      'totalSellQuantity': 0,
#      'bidQty': 0,
#      'bidprice': 0,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '31-Dec-2026',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '31-Dec-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY31-12-2026PE12000.00',
#      'openInterest': 12,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 200,
#      'bidQty': 50,
#      'bidprice': 350,
#      'askQty': 50,
#      'askPrice': 665,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY30-03-2023PE12000.00',
#      'openInterest': 22,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 7200,
#      'totalSellQuantity': 0,
#      'bidQty': 6800,
#      'bidprice': 21.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE12000.00',
#      'openInterest': 22,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 850,
#      'totalSellQuantity': 50,
#      'bidQty': 750,
#      'bidprice': 14.45,
#      'askQty': 50,
#      'askPrice': 70.95,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-09-2023PE12000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12000,
#     'expiryDate': '28-Dec-2023',
#     'PE': {'strikePrice': 12000,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023PE12000.00',
#      'openInterest': 50,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 30.76,
#      'lastPrice': 152.05,
#      'change': -24,
#      'pChange': -13.632490769667708,
#      'totalBuyQuantity': 400,
#      'totalSellQuantity': 300,
#      'bidQty': 50,
#      'bidprice': 155,
#      'askQty': 50,
#      'askPrice': 190,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12100,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12100,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12100.00',
#      'openInterest': 212.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12100,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 12100,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE12100.00',
#      'openInterest': 61.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1250,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 5.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12200,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 12200,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE12200.00',
#      'openInterest': 14,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1650,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 15.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12200,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12200,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12200.00',
#      'openInterest': 223.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12300,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12300,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12300.00',
#      'openInterest': 120,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.15,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12500.00',
#      'openInterest': 443.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 47750,
#      'totalSellQuantity': 0,
#      'bidQty': 45550,
#      'bidprice': 3.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12600,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12600,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12600.00',
#      'openInterest': 93.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12700,
#     'expiryDate': '28-Dec-2023',
#     'PE': {'strikePrice': 12700,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023PE12700.00',
#      'openInterest': 9,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1200,
#      'totalSellQuantity': 0,
#      'bidQty': 50,
#      'bidprice': 133.55,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12700,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12700,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12700.00',
#      'openInterest': 238,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.45,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12800,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12800,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12800.00',
#      'openInterest': 56,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.6,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 12900,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 12900,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE12900.00',
#      'openInterest': 92,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 3.8,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-09-2023PE13000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '28-Dec-2023',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023PE13000.00',
#      'openInterest': 182,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 31.33,
#      'lastPrice': 280,
#      'change': -15,
#      'pChange': -5.084745762711865,
#      'totalBuyQuantity': 1100,
#      'totalSellQuantity': 600,
#      'bidQty': 50,
#      'bidprice': 243,
#      'askQty': 50,
#      'askPrice': 274,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '24-Dec-2025',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '24-Dec-2025',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY24-12-2025PE13000.00',
#      'openInterest': 3,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 800,
#      'totalSellQuantity': 50,
#      'bidQty': 750,
#      'bidprice': 300.05,
#      'askQty': 50,
#      'askPrice': 840.6,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '25-Jun-2026',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '25-Jun-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY25-06-2026PE13000.00',
#      'openInterest': 5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 850,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 303.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '31-Dec-2026',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '31-Dec-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY31-12-2026PE13000.00',
#      'openInterest': 2,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 100,
#      'totalSellQuantity': 100,
#      'bidQty': 50,
#      'bidprice': 478.05,
#      'askQty': 50,
#      'askPrice': 1100,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 13000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022CE13000.00',
#      'openInterest': 4796,
#      'changeinOpenInterest': 184,
#      'pchangeinOpenInterest': 3.98959236773634,
#      'totalTradedVolume': 234,
#      'impliedVolatility': 0,
#      'lastPrice': 4290,
#      'change': 267.9000000000001,
#      'pChange': 6.6606996345192835,
#      'totalBuyQuantity': 3700,
#      'totalSellQuantity': 3600,
#      'bidQty': 100,
#      'bidprice': 4275.5,
#      'askQty': 100,
#      'askPrice': 4300.05,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE13000.00',
#      'openInterest': 6745.5,
#      'changeinOpenInterest': 109,
#      'pchangeinOpenInterest': 1.6424320048218188,
#      'totalTradedVolume': 470,
#      'impliedVolatility': 32.34,
#      'lastPrice': 15.05,
#      'change': -4.699999999999999,
#      'pChange': -23.797468354430375,
#      'totalBuyQuantity': 16000,
#      'totalSellQuantity': 4700,
#      'bidQty': 2350,
#      'bidprice': 15,
#      'askQty': 1100,
#      'askPrice': 15.3,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY30-03-2023PE13000.00',
#      'openInterest': 257,
#      'changeinOpenInterest': 17,
#      'pchangeinOpenInterest': 7.083333333333333,
#      'totalTradedVolume': 109,
#      'impliedVolatility': 29.54,
#      'lastPrice': 58,
#      'change': -12.049999999999997,
#      'pChange': -17.20199857244825,
#      'totalBuyQuantity': 8300,
#      'totalSellQuantity': 950,
#      'bidQty': 50,
#      'bidprice': 57.8,
#      'askQty': 50,
#      'askPrice': 57.95,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 13000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE13000.00',
#      'openInterest': 72,
#      'changeinOpenInterest': -2,
#      'pchangeinOpenInterest': -2.7027027027027026,
#      'totalTradedVolume': 11,
#      'impliedVolatility': 28.88,
#      'lastPrice': 110,
#      'change': -15,
#      'pChange': -12,
#      'totalBuyQuantity': 1850,
#      'totalSellQuantity': 250,
#      'bidQty': 50,
#      'bidprice': 105.55,
#      'askQty': 50,
#      'askPrice': 113.95,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13100,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 13100,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE13100.00',
#      'openInterest': 42,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2000,
#      'totalSellQuantity': 0,
#      'bidQty': 1850,
#      'bidprice': 4.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13500,
#     'expiryDate': '28-Dec-2023',
#     'PE': {'strikePrice': 13500,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023PE13500.00',
#      'openInterest': 236,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 250,
#      'totalSellQuantity': 200,
#      'bidQty': 50,
#      'bidprice': 300,
#      'askQty': 50,
#      'askPrice': 380,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13500,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 13500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022CE13500.00',
#      'openInterest': 200,
#      'changeinOpenInterest': 15,
#      'pchangeinOpenInterest': 8.108108108108109,
#      'totalTradedVolume': 16,
#      'impliedVolatility': 0,
#      'lastPrice': 3805.35,
#      'change': 268.9499999999998,
#      'pChange': 7.6051917203936155,
#      'totalBuyQuantity': 2100,
#      'totalSellQuantity': 2300,
#      'bidQty': 50,
#      'bidprice': 3812.75,
#      'askQty': 50,
#      'askPrice': 3893.8,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 13500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-12-2022PE13500.00',
#      'openInterest': 1038,
#      'changeinOpenInterest': 173,
#      'pchangeinOpenInterest': 20,
#      'totalTradedVolume': 361,
#      'impliedVolatility': 30.08,
#      'lastPrice': 19.45,
#      'change': -7.050000000000001,
#      'pChange': -26.603773584905667,
#      'totalBuyQuantity': 17450,
#      'totalSellQuantity': 4800,
#      'bidQty': 50,
#      'bidprice': 19.1,
#      'askQty': 200,
#      'askPrice': 19.35,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 13500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY29-06-2023PE13500.00',
#      'openInterest': 32,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 1000,
#      'bidQty': 800,
#      'bidprice': 105.05,
#      'askQty': 750,
#      'askPrice': 174.95,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 13950,
#     'expiryDate': '27-Oct-2022',
#     'CE': {'strikePrice': 13950,
#      'expiryDate': '27-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY27-10-2022CE13950.00',
#      'openInterest': 5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6150,
#      'totalSellQuantity': 5600,
#      'bidQty': 100,
#      'bidprice': 3311.55,
#      'askQty': 50,
#      'askPrice': 3432,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 13950,
#      'expiryDate': '27-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY27-10-2022PE13950.00',
#      'openInterest': 181,
#      'changeinOpenInterest': 106,
#      'pchangeinOpenInterest': 141.33333333333334,
#      'totalTradedVolume': 295,
#      'impliedVolatility': 44.21,
#      'lastPrice': 1.75,
#      'change': -0.5,
#      'pChange': -22.22222222222222,
#      'totalBuyQuantity': 18050,
#      'totalSellQuantity': 30400,
#      'bidQty': 200,
#      'bidprice': 1.5,
#      'askQty': 50,
#      'askPrice': 2.05,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 14000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 14000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY30-03-2023PE14000.00',
#      'openInterest': 780,
#      'changeinOpenInterest': 57,
#      'pchangeinOpenInterest': 7.8838174273858925,
#      'totalTradedVolume': 224,
#      'impliedVolatility': 26.71,
#      'lastPrice': 95,
#      'change': -24.849999999999994,
#      'pChange': -20.734251147267415,
#      'totalBuyQuantity': 10050,
#      'totalSellQuantity': 2950,
#      'bidQty': 50,
#      'bidprice': 90.1,
#      'askQty': 150,
#      'askPrice': 95.95,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 14000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY30-03-2023CE14000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 0,
#      'totalSellQuantity': 600,
#      'bidQty': 0,
#      'bidprice': 0,
#      'askQty': 600,
#      'askPrice': 4513.8,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 14000,
#     'expiryDate': '28-Dec-2023',
#     'PE': {'strikePrice': 14000,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023PE14000.00',
#      'openInterest': 821,
#      'changeinOpenInterest': 8,
#      'pchangeinOpenInterest': 0.984009840098401,
#      'totalTradedVolume': 13,
#      'impliedVolatility': 31.24,
#      'lastPrice': 440,
#      'change': -20,
#      'pChange': -4.3478260869565215,
#      'totalBuyQuantity': 850,
#      'totalSellQuantity': 250,
#      'bidQty': 350,
#      'bidprice': 425,
#      'askQty': 50,
#      'askPrice': 448.8,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 14000,
#      'expiryDate': '28-Dec-2023',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY28-12-2023CE14000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 0,
#      'totalSellQuantity': 600,
#      'bidQty': 0,
#      'bidprice': 0,
#      'askQty': 600,
#      'askPrice': 5450.1,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 14000,
#     'expiryDate': '27-Jun-2024',
#     'PE': {'strikePrice': 14000,
#      'expiryDate': '27-Jun-2024',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY27-06-2024PE14000.00',
#      'openInterest': 197.5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1050,
#      'totalSellQuantity': 50,
#      'bidQty': 750,
#      'bidprice': 302.05,
#      'askQty': 50,
#      'askPrice': 850,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 14000,
#     'expiryDate': '24-Dec-2025',
#     'PE': {'strikePrice': 14000,
#      'expiryDate': '24-Dec-2025',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY24-12-2025PE14000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 14000,
#     'expiryDate': '25-Jun-2026',
#     'PE': {'strikePrice': 14000,
#      'expiryDate': '25-Jun-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY25-06-2026PE14000.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 750,
#      'totalSellQuantity': 0,
#      'bidQty': 750,
#      'bidprice': 500.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 14000,
#     'expiryDate': '31-Dec-2026',
#     'PE': {'strikePrice': 14000,
#      'expiryDate': '31-Dec-2026',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY31-12-2026PE14000.00',
#      'openInterest': 19,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 550,
#      'totalSellQuantity': 100,
#      'bidQty': 50,
#      'bidprice': 800,
#      'askQty': 50,
#      'askPrice': 1256.9,
#      'underlyingValue': 17308.3}},
# ...
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9800,
#      'totalSellQuantity': 9800,
#      'bidQty': 1500,
#      'bidprice': 2403.25,
#      'askQty': 1500,
#      'askPrice': 2477.7,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 19800,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 19800,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE19800.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9800,
#      'totalSellQuantity': 14050,
#      'bidQty': 1500,
#      'bidprice': 2455.15,
#      'askQty': 2500,
#      'askPrice': 2573.6,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 19800,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE19800.00',
#      'openInterest': 94,
#      'changeinOpenInterest': 74,
#      'pchangeinOpenInterest': 370,
#      'totalTradedVolume': 287,
#      'impliedVolatility': 37.26,
#      'lastPrice': 0.7,
#      'change': -0.44999999999999996,
#      'pChange': -39.130434782608695,
#      'totalBuyQuantity': 138500,
#      'totalSellQuantity': 20350,
#      'bidQty': 2500,
#      'bidprice': 0.65,
#      'askQty': 450,
#      'askPrice': 0.75,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 19850,
#     'expiryDate': '20-Oct-2022',
#     'CE': {'strikePrice': 19850,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE19850.00',
#      'openInterest': 42,
#      'changeinOpenInterest': 42,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 79,
#      'impliedVolatility': 38.14,
#      'lastPrice': 0.75,
#      'change': -1.15,
#      'pChange': -60.526315789473685,
#      'totalBuyQuantity': 155500,
#      'totalSellQuantity': 14200,
#      'bidQty': 1500,
#      'bidprice': 0.55,
#      'askQty': 1500,
#      'askPrice': 0.85,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 19850,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE19850.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8800,
#      'totalSellQuantity': 9800,
#      'bidQty': 1800,
#      'bidprice': 2503.9,
#      'askQty': 1500,
#      'askPrice': 2619.15,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 19900,
#     'expiryDate': '20-Oct-2022',
#     'CE': {'strikePrice': 19900,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE19900.00',
#      'openInterest': 132,
#      'changeinOpenInterest': 80,
#      'pchangeinOpenInterest': 153.84615384615384,
#      'totalTradedVolume': 286,
#      'impliedVolatility': 38.78,
#      'lastPrice': 0.75,
#      'change': -0.30000000000000004,
#      'pChange': -28.571428571428577,
#      'totalBuyQuantity': 121700,
#      'totalSellQuantity': 111050,
#      'bidQty': 500,
#      'bidprice': 0.7,
#      'askQty': 2250,
#      'askPrice': 0.8,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 19900,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE19900.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9800,
#      'totalSellQuantity': 9800,
#      'bidQty': 4250,
#      'bidprice': 2450.55,
#      'askQty': 1500,
#      'askPrice': 2669.1,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 19950,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 19950,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE19950.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9800,
#      'totalSellQuantity': 9800,
#      'bidQty': 1500,
#      'bidprice': 2454.95,
#      'askQty': 1500,
#      'askPrice': 2719.25,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 19950,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE19950.00',
#      'openInterest': 46,
#      'changeinOpenInterest': 31,
#      'pchangeinOpenInterest': 206.66666666666666,
#      'totalTradedVolume': 133,
#      'impliedVolatility': 39.66,
#      'lastPrice': 0.8,
#      'change': -1.0999999999999999,
#      'pChange': -57.89473684210525,
#      'totalBuyQuantity': 128400,
#      'totalSellQuantity': 18500,
#      'bidQty': 2050,
#      'bidprice': 0.6,
#      'askQty': 2800,
#      'askPrice': 1,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20000,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 20000,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20000.00',
#      'openInterest': 12,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 9.090909090909092,
#      'totalTradedVolume': 3,
#      'impliedVolatility': 0,
#      'lastPrice': 2651,
#      'change': -473.9000000000001,
#      'pChange': -15.165285289129255,
#      'totalBuyQuantity': 10300,
#      'totalSellQuantity': 10200,
#      'bidQty': 250,
#      'bidprice': 2666.55,
#      'askQty': 250,
#      'askPrice': 2767.3,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 20000,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20000.00',
#      'openInterest': 25382,
#      'changeinOpenInterest': -3843,
#      'pchangeinOpenInterest': -13.149700598802395,
#      'totalTradedVolume': 16952,
#      'impliedVolatility': 39.77,
#      'lastPrice': 0.7,
#      'change': -0.44999999999999996,
#      'pChange': -39.130434782608695,
#      'totalBuyQuantity': 1178850,
#      'totalSellQuantity': 296350,
#      'bidQty': 38600,
#      'bidprice': 0.65,
#      'askQty': 35550,
#      'askPrice': 0.7,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20050,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 20050,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20050.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 11050,
#      'totalSellQuantity': 11050,
#      'bidQty': 4550,
#      'bidprice': 2469.95,
#      'askQty': 1000,
#      'askPrice': 2848.8,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 20050,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20050.00',
#      'openInterest': 121,
#      'changeinOpenInterest': 65,
#      'pchangeinOpenInterest': 116.07142857142857,
#      'totalTradedVolume': 349,
#      'impliedVolatility': 40.66,
#      'lastPrice': 0.75,
#      'change': -0.44999999999999996,
#      'pChange': -37.5,
#      'totalBuyQuantity': 117000,
#      'totalSellQuantity': 106400,
#      'bidQty': 900,
#      'bidprice': 0.65,
#      'askQty': 1500,
#      'askPrice': 0.85,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20100,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 20100,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20100.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 11050,
#      'totalSellQuantity': 11050,
#      'bidQty': 2750,
#      'bidprice': 2514,
#      'askQty': 1000,
#      'askPrice': 2901.15,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 20100,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20100.00',
#      'openInterest': 137,
#      'changeinOpenInterest': 116,
#      'pchangeinOpenInterest': 552.3809523809524,
#      'totalTradedVolume': 1247,
#      'impliedVolatility': 41.01,
#      'lastPrice': 0.7,
#      'change': -0.40000000000000013,
#      'pChange': -36.36363636363637,
#      'totalBuyQuantity': 111700,
#      'totalSellQuantity': 26150,
#      'bidQty': 2950,
#      'bidprice': 0.65,
#      'askQty': 500,
#      'askPrice': 0.7,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20150,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 20150,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20150.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8300,
#      'totalSellQuantity': 8300,
#      'bidQty': 4550,
#      'bidprice': 2558.2,
#      'askQty': 1800,
#      'askPrice': 2890.75,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 20150,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20150.00',
#      'openInterest': 142,
#      'changeinOpenInterest': 96,
#      'pchangeinOpenInterest': 208.69565217391303,
#      'totalTradedVolume': 210,
#      'impliedVolatility': 41.34,
#      'lastPrice': 0.65,
#      'change': -0.85,
#      'pChange': -56.666666666666664,
#      'totalBuyQuantity': 87700,
#      'totalSellQuantity': 114950,
#      'bidQty': 900,
#      'bidprice': 0.65,
#      'askQty': 1700,
#      'askPrice': 0.85,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20200,
#     'expiryDate': '20-Oct-2022',
#     'CE': {'strikePrice': 20200,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20200.00',
#      'openInterest': 178,
#      'changeinOpenInterest': 137,
#      'pchangeinOpenInterest': 334.1463414634146,
#      'totalTradedVolume': 1299,
#      'impliedVolatility': 42.24,
#      'lastPrice': 0.7,
#      'change': -0.44999999999999996,
#      'pChange': -39.130434782608695,
#      'totalBuyQuantity': 100000,
#      'totalSellQuantity': 117500,
#      'bidQty': 1300,
#      'bidprice': 0.65,
#      'askQty': 500,
#      'askPrice': 0.7,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 20200,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20200.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 11050,
#      'totalSellQuantity': 11050,
#      'bidQty': 4550,
#      'bidprice': 2612.7,
#      'askQty': 1000,
#      'askPrice': 3007.15,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20250,
#     'expiryDate': '20-Oct-2022',
#     'CE': {'strikePrice': 20250,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20250.00',
#      'openInterest': 88,
#      'changeinOpenInterest': 80,
#      'pchangeinOpenInterest': 1000,
#      'totalTradedVolume': 150,
#      'impliedVolatility': 42.56,
#      'lastPrice': 0.65,
#      'change': -0.5499999999999999,
#      'pChange': -45.83333333333333,
#      'totalBuyQuantity': 77650,
#      'totalSellQuantity': 98650,
#      'bidQty': 350,
#      'bidprice': 0.6,
#      'askQty': 950,
#      'askPrice': 0.7,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 20250,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20250.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8300,
#      'totalSellQuantity': 11050,
#      'bidQty': 1800,
#      'bidprice': 2903.45,
#      'askQty': 1000,
#      'askPrice': 3064.75,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20300,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 20300,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20300.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8300,
#      'totalSellQuantity': 11100,
#      'bidQty': 4550,
#      'bidprice': 2692.9,
#      'askQty': 50,
#      'askPrice': 3031,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 20300,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20300.00',
#      'openInterest': 347,
#      'changeinOpenInterest': 69,
#      'pchangeinOpenInterest': 24.820143884892087,
#      'totalTradedVolume': 506,
#      'impliedVolatility': 43.75,
#      'lastPrice': 0.65,
#      'change': -0.4,
#      'pChange': -38.095238095238095,
#      'totalBuyQuantity': 122500,
#      'totalSellQuantity': 104050,
#      'bidQty': 11200,
#      'bidprice': 0.65,
#      'askQty': 1300,
#      'askPrice': 0.75,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20350,
#     'expiryDate': '20-Oct-2022',
#     'PE': {'strikePrice': 20350,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20350.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8300,
#      'totalSellQuantity': 8300,
#      'bidQty': 2750,
#      'bidprice': 2738.4,
#      'askQty': 1800,
#      'askPrice': 3089.8,
#      'underlyingValue': 17308.3},
#     'CE': {'strikePrice': 20350,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20350.00',
#      'openInterest': 172,
#      'changeinOpenInterest': 113,
#      'pchangeinOpenInterest': 191.52542372881356,
#      'totalTradedVolume': 352,
#      'impliedVolatility': 43.44,
#      'lastPrice': 0.6,
#      'change': -0.6,
#      'pChange': -50,
#      'totalBuyQuantity': 85450,
#      'totalSellQuantity': 101800,
#      'bidQty': 1850,
#      'bidprice': 0.6,
#      'askQty': 1300,
#      'askPrice': 0.7,
#      'underlyingValue': 17308.3}},
#    {'strikePrice': 20400,
#     'expiryDate': '20-Oct-2022',
#     'CE': {'strikePrice': 20400,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022CE20400.00',
#      'openInterest': 17857,
#      'changeinOpenInterest': -4281,
#      'pchangeinOpenInterest': -19.33779022495257,
#      'totalTradedVolume': 14310,
#      'impliedVolatility': 44.37,
#      'lastPrice': 0.7,
#      'change': -0.40000000000000013,
#      'pChange': -36.36363636363637,
#      'totalBuyQuantity': 608200,
#      'totalSellQuantity': 234050,
#      'bidQty': 17150,
#      'bidprice': 0.65,
#      'askQty': 39700,
#      'askPrice': 0.7,
#      'underlyingValue': 17308.3},
#     'PE': {'strikePrice': 20400,
#      'expiryDate': '20-Oct-2022',
#      'underlying': 'NIFTY',
#      'identifier': 'OPTIDXNIFTY20-10-2022PE20400.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9900,
#      'totalSellQuantity': 9900,
#      'bidQty': 250,
#      'bidprice': 3020.45,
#      'askQty': 250,
#      'askPrice': 3166.25,
#      'underlyingValue': 17308.3}}],
#   'CE': {'totOI': 1348066, 'totVol': 11724205},
#   'PE': {'totOI': 1263959, 'totVol': 10714851}}}

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['records', 'filtered'])

# %%
type(data['filtered'])
# Out:
# dict

# %%
data['filtered'].keys()
# Out:
# dict_keys(['data', 'CE', 'PE'])

# %%
data['filtered']['CE']
# Out:
# {'totOI': 1348066, 'totVol': 11724205}

# %%
totCE = data['filtered']['CE']['totOI']

# %%
totCE
# Out:
# 1348066

# %%
totPE = data['filtered']['PE']['totOI']

# %%
PCR= totPE/totCE

# %%
print(PCR)
# Out:
# 0.9376091378315305
